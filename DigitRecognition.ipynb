# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os

from keras.preprocessing import image

from tensorflow.keras.models import load_model

# %% [markdown]
# Pridiction On Unseen Data using DigitRecognition Model

# %%
model = load_model(r"./Models/HandWrittenDigitModel.keras")

# %%
img = image.load_img('./Demo/Digit00.jpeg', target_size=(28, 28))
print(img.format)
print(img.size)
print(img.mode)
# Out:
# None
# (28, 28)
# RGB

# %%
x = np.asarray(img)
plt.matshow(x)

# %%
#invert Image
x = 255-x

plt.matshow(x)

# %%
# Convert the image to grayscale
x = np.dot(x[..., :3], [100.0, 100.0, 110.0])

plt.matshow(x)

# %%
#Normalisation
x=x/255

#Flattening
x_flattened = x.reshape(28*28)

print("New Shape After Flattening : ",x_flattened.shape)
# Out:
# New Shape After Flattening :  (784,)

# %%
res = model.predict( np.array( [x_flattened,] )  )

print("Model Pridiction :",res)

print("Prediction Result : ", np.argmax(res))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000027D33D544C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Model Pridiction : [[0.9775247  0.02099189 0.8993312  0.01015922 0.12055644 0.01355804
#   0.02113413 0.6047027  0.15407678 0.35978547]]
# Prediction Result :  0
